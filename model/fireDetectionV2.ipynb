# %%
# !nvidia-smi
# Out:
# Sat Nov 25 18:09:13 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    24W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 646.0/646.0 kB 9.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Ultralytics YOLOv8.0.220 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 26.9/166.8 GB disk)
#
# OS                  Linux-5.15.120+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.10.12
# Install             pip
# RAM                 51.00 GB
# CPU                 Intel Xeon 2.00GHz
# CUDA                11.8
#
# matplotlib          ✅ 3.7.1>=3.3.0
# numpy               ✅ 1.23.5>=1.22.2
# opencv-python       ✅ 4.8.0.76>=4.6.0
# pillow              ✅ 9.4.0>=7.1.2
# pyyaml              ✅ 6.0.1>=5.3.1
# requests            ✅ 2.31.0>=2.23.0
# scipy               ✅ 1.11.3>=1.4.1
# torch               ✅ 2.1.0+cu118>=1.8.0
# torchvision         ✅ 0.16.0+cu118>=0.9.0
# tqdm                ✅ 4.66.1>=4.64.0
# pandas              ✅ 1.5.3>=1.1.4
# seaborn             ✅ 0.12.2>=0.11.0
# psutil              ✅ 5.9.5
# py-cpuinfo          ✅ 9.0.0
# thop                ✅ 0.1.1-2209072238>=0.1.1

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key=API_KEY)
project = rf.workspace("school-d1cgr").project("wildfire-8hbqw")
dataset = project.version(3).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 kB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 37.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 10.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 9.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
#     Uninstalling opencv-python-headless-4.8.1.78:
#       Successfully uninstalled opencv-python-headless-4.8.1.78
# ...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/wildfire-3/data.yaml epochs = 80 imgsz = 640 patience = 10
# Out:
# Ultralytics YOLOv8.0.220 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
# !zip -r /content/train2.zip /content/runs/detect/train2
# Out:
#   adding: content/runs/detect/train2/ (stored 0%)
#   adding: content/runs/detect/train2/results.csv (deflated 85%)
#   adding: content/runs/detect/train2/train_batch2.jpg (deflated 3%)
#   adding: content/runs/detect/train2/labels.jpg (deflated 17%)
#   adding: content/runs/detect/train2/train_batch91560.jpg (deflated 7%)
#   adding: content/runs/detect/train2/PR_curve.png (deflated 14%)
#   adding: content/runs/detect/train2/val_batch0_labels.jpg (deflated 7%)
#   adding: content/runs/detect/train2/val_batch1_pred.jpg (deflated 6%)
#   adding: content/runs/detect/train2/F1_curve.png (deflated 13%)
#   adding: content/runs/detect/train2/val_batch0_pred.jpg (deflated 6%)
#   adding: content/runs/detect/train2/R_curve.png (deflated 13%)
#   adding: content/runs/detect/train2/val_batch2_labels.jpg (deflated 7%)
#   adding: content/runs/detect/train2/P_curve.png (deflated 13%)
#   adding: content/runs/detect/train2/events.out.tfevents.1701284720.dc0c86ab07e6.2527.0 (deflated 75%)
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/runs/detect/train2/results.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-2ef00afeb5c7> in <cell line: 1>()
# ----> 1 df = pd.read_csv("/content/runs/detect/train2/results.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df.head()
# Out:
#                      epoch           train/box_loss           train/cls_loss  \
# 0                        1                  0.84927                  1.24880
# 1                        2                  0.70939                  0.82924
# 2                        3                  0.74084                  0.85614
# 3                        4                  0.73990                  0.85806
# 4                        5                  0.70720                  0.81247
#
#             train/dfl_loss     metrics/precision(B)        metrics/recall(B)  \
# 0                   1.1560                  0.82690                  0.69286
# 1                   1.0598                  0.85666                  0.72822
# 2                   1.0789                  0.84019                  0.72508
# 3                   1.0835                  0.86203                  0.74137
# 4                   1.0712                  0.85838                  0.74355
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0                     epoch  80 non-null     int64
#  1            train/box_loss  80 non-null     float64
#  2            train/cls_loss  80 non-null     float64
#  3            train/dfl_loss  80 non-null     float64
#  4      metrics/precision(B)  80 non-null     float64
#  5         metrics/recall(B)  80 non-null     float64
#  6          metrics/mAP50(B)  80 non-null     float64
#  7       metrics/mAP50-95(B)  80 non-null     float64
#  8              val/box_loss  80 non-null     float64
#  9              val/cls_loss  80 non-null     float64
#  10             val/dfl_loss  80 non-null     float64
#  11                   lr/pg0  80 non-null     float64
#  12                   lr/pg1  80 non-null     float64
#  13                   lr/pg2  80 non-null     float64
# ...

# %%
df['epoch'].iloc[1:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-40d5d8fdfea9> in <cell line: 1>()
# ----> 1 df['epoch'].iloc[1:10]
#
# NameError: name 'df' is not defined
